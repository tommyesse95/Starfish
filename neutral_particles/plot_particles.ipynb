# %%
from matplotlib import pyplot as plt 
import pandas as pd
from scipy import interpolate 


# Import data taken with graph reader 


data_neutral = pd.read_csv('data_neutrals.csv', header=None, names=('It', 'Part')) #  (spwt=1e10)

dt = 1e-8

# Compute time simulation 
data_neutral['It'] *= dt

plt.figure(figsize=(8,5), dpi=100)



# Plot 
plt.plot (data_neutral.It, data_neutral.Part, 'ko--')
plt.xscale("log")
plt.yscale("log")

# Plot Edit 
plt.xlabel('Time_sim (s)')
plt.ylabel('Part_sim')
plt.title('Particles simulated (dt=1e-8, spwt=1e10)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})



# X, Y axis Tickmarks (scale of your graph) put here the values of Sparc. 
plt.xticks([])
plt.yticks([30000, 35000, 40000, 45000, 48800])

plt.grid(True)


# Save figure (dpi 300 is good when saving so graph has high resolution)
# plt.savefig('breakdown_voltage2.png', dpi=300)

plt.show()

data_neutral.It
# Out:
# 0    0.00000
# 1    0.00005
# 2    0.00006
# 3    0.00007
# 4    0.00009
# 5    0.00010
# 6    0.00020
# 7    0.00030
# 8    0.00035
# 9    0.00050
# Name: It, dtype: float64
